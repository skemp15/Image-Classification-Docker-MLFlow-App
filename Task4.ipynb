# %% [markdown]
# # Connecting the Datasets

# %% [markdown]
# This notebook will combine our datasets and look into what impact consumer events have on mortgage state.

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load, view and merge datasets

# %%
# Load datasets
app_df = pd.read_csv('applicant.csv')
evt_df = pd.read_csv('event.csv')
mtg_df = pd.read_csv('mortgage.csv')

# View datasets
display(app_df.head(2))
display(evt_df.head(2))
display(mtg_df.head(2))
# Out:
#                        applicant_id             applicant_mortgage_id
# 0  ccc6ff06ea696696b4297f1dbf727350  a9e9412e0f8af6080bb3fbc717796549  \
# 1  337e4de1829895a00c73fc37917bf066  634ede757f052342e036b0ad6d22d303
#
#               applicant_consumer_id
# 0  01ebee02ac29462580e70365033564b0
# 1  47cdf18b3fe4aa332ee352c2926783c6
#                            event_id  event_type      event_created_at
# 0  d22abb371f9c3f11346f4c7be25090e9  email_open  2020-12-01T07:51:31Z  \
# 1  fa82669e074cf6238d5da6fefe4d0418  email_sent  2022-05-09T09:31:37Z
#
#                   event_consumer_id
# 0  01978065ceee79b338d479bd5eac41da
# 1  ff5a2159a4a246182a412fed5d68487d
#                         mortgage_id   mortgage_type mortgage_payment_type
# 0  1ad9ba91c6541dd973cc924b6db7e311  owner_occupied             repayment  \
# 1  317ac7153428730d726b5a4b7a71122b  owner_occupied             repayment
#
#    mortgage_property_value  mortgage_loan_amount  mortgage_initial_rate
# 0                   550000                290000                    2.2  \
# 1                   100000                 70000                    2.9
#
#   mortgage_scheme mortgage_state_updated
# 0           fixed                   open
# 1           fixed         not_interested

# %% [markdown]
# We can see that we can merge the applicant and mortgage dataframes on applicant_consumer_id and event_consumer_id, and subsquently merge this on applicant_mortgage_id and mortgage_id:

# %%
# Rename columns
app_df.rename(columns={'applicant_consumer_id': 'consumer_id', 'applicant_mortgage_id': 'mortgage_id'}, inplace=True)
evt_df.rename(columns={'event_consumer_id': 'consumer_id'}, inplace=True)

# Merge dataframes
merge_df = pd.merge(app_df, evt_df, on='consumer_id', how='inner')
df = pd.merge(merge_df, mtg_df, on='mortgage_id', how='inner')

# %% [markdown]
# We can look at our new dataframe:

# %%
df.describe(include='all').T
# Out:
#                            count unique                               top
# applicant_id               48565   1932  5cfad988a68337e7629afa7de36500e4  \
# mortgage_id                48565   1932  feaea1c15ad08db0762cf14196c4314c
# consumer_id                48565   1842  b7730d37a71e86ea762a5367a9e88bf9
# event_id                   48565  45370  10cee16ef7f12ffaff79bbc7588d0b98
# event_type                 48565      7                        email_open
# event_created_at           48565  31084              2021-09-14T08:01:34Z
# mortgage_type              48565      2                    owner_occupied
# mortgage_payment_type      48565      3                         repayment
# mortgage_property_value  48565.0    NaN                               NaN
# mortgage_loan_amount     48565.0    NaN                               NaN
# mortgage_initial_rate    48565.0    NaN                               NaN
# mortgage_scheme            48565      2                             fixed
# mortgage_state_updated     48565      5                          retained
#
#                           freq           mean            std      min
# applicant_id               623            NaN            NaN      NaN  \
# mortgage_id                623            NaN            NaN      NaN
# consumer_id                623            NaN            NaN      NaN
# event_id                     4            NaN            NaN      NaN
# event_type               26098            NaN            NaN      NaN
# event_created_at           918            NaN            NaN      NaN
# mortgage_type            48148            NaN            NaN      NaN
# mortgage_payment_type    47448            NaN            NaN      NaN
# mortgage_property_value    NaN  298565.015958   207190.97707  40000.0
# mortgage_loan_amount       NaN   149373.21116  106069.950383  10000.0
# mortgage_initial_rate      NaN       2.033438       0.611452      0.9
# mortgage_scheme          47117            NaN            NaN      NaN
# mortgage_state_updated   14365            NaN            NaN      NaN
#
#                               25%       50%       75%        max
# applicant_id                  NaN       NaN       NaN        NaN
# mortgage_id                   NaN       NaN       NaN        NaN
# consumer_id                   NaN       NaN       NaN        NaN
# event_id                      NaN       NaN       NaN        NaN
# event_type                    NaN       NaN       NaN        NaN
# event_created_at              NaN       NaN       NaN        NaN
# mortgage_type                 NaN       NaN       NaN        NaN
# mortgage_payment_type         NaN       NaN       NaN        NaN
# mortgage_property_value  170000.0  250000.0  380000.0  9500000.0
# mortgage_loan_amount      90000.0  130000.0  180000.0  2280000.0
# mortgage_initial_rate         1.7       2.0       2.2        6.0
# mortgage_scheme               NaN       NaN       NaN        NaN
# mortgage_state_updated        NaN       NaN       NaN        NaN

# %%
df.head()
# Out:
#                        applicant_id                       mortgage_id
# 0  ccc6ff06ea696696b4297f1dbf727350  a9e9412e0f8af6080bb3fbc717796549  \
# 1  ccc6ff06ea696696b4297f1dbf727350  a9e9412e0f8af6080bb3fbc717796549
# 2  337e4de1829895a00c73fc37917bf066  634ede757f052342e036b0ad6d22d303
# 3  2730b41d0474e03194055d3ebce3c33b  e2b5ea63e8b163308787d05250ce71ad
# 4  2730b41d0474e03194055d3ebce3c33b  e2b5ea63e8b163308787d05250ce71ad
#
#                         consumer_id                          event_id
# 0  01ebee02ac29462580e70365033564b0  59621e0c159c1e6889f215e24dc46154  \
# 1  01ebee02ac29462580e70365033564b0  f9ad79ba968698f44113dc945970d32c
# 2  47cdf18b3fe4aa332ee352c2926783c6  f27046a6716ef26c6c41edc5aaeaab54
# 3  e7b37f9f4603b3b56aaf9ccba7133fb6  96efbf98d7bc994aa3956e0489382669
# 4  e7b37f9f4603b3b56aaf9ccba7133fb6  a5935711388ffdebb5adda1c3f026d3b
#
#    event_type      event_created_at   mortgage_type mortgage_payment_type
# 0  email_sent  2021-08-30T08:01:45Z  owner_occupied             repayment  \
# 1  email_open  2021-08-30T08:21:43Z  owner_occupied             repayment
# 2  email_sent  2021-08-30T08:01:45Z  owner_occupied             repayment
# 3  email_sent  2022-05-23T09:31:14Z  owner_occupied             repayment
# 4  email_sent  2022-06-06T09:40:58Z  owner_occupied             repayment
#
#    mortgage_property_value  mortgage_loan_amount  mortgage_initial_rate
# 0                   190000                100000                    2.5  \
# 1                   190000                100000                    2.5
# 2                   420000                100000                    2.1
# 3                   420000                190000                    1.8
# 4                   420000                190000                    1.8
#
#   mortgage_scheme mortgage_state_updated
# 0           fixed                   open
# 1           fixed                   open
# 2           fixed                   open
# 3           fixed                   open
# 4           fixed                   open

# %% [markdown]
# We can group this data by mortgage state and event type to show how many instance of different combinations there are:

# %%
# Group by mortgage_state_updated and event_type to count occurrences
impact_analysis = df.groupby(['mortgage_state_updated', 'event_type']).size().unstack(fill_value=0)

impact_analysis
# Out:
# event_type              account_created  blog_post_read  call_requested
# mortgage_state_updated
# found_refinance                      18              31              20  \
# lost                                 59              39              48
# not_interested                      112             122             112
# open                                163             190             119
# retained                            236             241             373
#
# event_type              email_open  email_sent  logged_in  pageview
# mortgage_state_updated
# found_refinance                633         371         32       222
# lost                          6356        3700         34       532
# not_interested                4733        1334        149      1950
# open                          6358        4026        111      2626
# retained                      8018        2018        264      3215

# %%
# Calculate the total count for each state of mortgage
total_counts_mtg_state = impact_analysis.sum(axis=1)

# Convert the counts to percentages
impact_analysis_percentage_mtg_state = impact_analysis.div(total_counts_mtg_state, axis=0) * 100

impact_analysis_percentage_mtg_state
# Out:
# event_type              account_created  blog_post_read  call_requested
# mortgage_state_updated
# found_refinance                1.356443        2.336096        1.507159  \
# lost                           0.547920        0.362184        0.445765
# not_interested                 1.315789        1.433271        1.315789
# open                           1.199147        1.397778        0.875451
# retained                       1.642882        1.677689        2.596589
#
# event_type              email_open  email_sent  logged_in   pageview
# mortgage_state_updated
# found_refinance          47.701583   27.957800   2.411454  16.729465
# lost                     59.026746   34.361070   0.315750   4.940565
# not_interested           55.603853   15.671992   1.750470  22.908835
# open                     46.774075   29.618186   0.816597  19.318767
# retained                 55.816220   14.048033   1.837800  22.380787

# %%
# Calculate the total count for each event type
total_counts_evt_type = impact_analysis.sum(axis=0)

# Convert the counts to percentages
impact_analysis_percentage_evt_type = impact_analysis.div(total_counts_evt_type, axis=1) * 100

impact_analysis_percentage_evt_type
# Out:
# event_type              account_created  blog_post_read  call_requested
# mortgage_state_updated
# found_refinance                3.061224        4.975923        2.976190  \
# lost                          10.034014        6.260032        7.142857
# not_interested                19.047619       19.582665       16.666667
# open                          27.721088       30.497592       17.708333
# retained                      40.136054       38.683788       55.505952
#
# event_type              email_open  email_sent  logged_in   pageview
# mortgage_state_updated
# found_refinance           2.425473    3.240458   5.423729   2.598011
# lost                     24.354357   32.317233   5.762712   6.225863
# not_interested           18.135489   11.651673  25.254237  22.820363
# open                     24.362020   35.164643  18.813559  30.731422
# retained                 30.722661   17.625994  44.745763  37.624342
