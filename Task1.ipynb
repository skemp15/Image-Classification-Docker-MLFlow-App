# %% [markdown]
# # Task 1 - Input Data

# %% [markdown]
# This notebook will aim to analyse the raw data that we want to import into our system. We will perform exploratory data analysis on the data, identify irregularities and potential problems and ultimately clean the data so that we can avoid bad data entering our database.

# %% [markdown]
# ### Import Data

# %% [markdown]
# First we can import our necessary libraries:

# %%
# Import libraries
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.impute import KNNImputer

# %% [markdown]
# Next we can load our data and view the first few rows:

# %%
# Load data and view top rows
df = pd.read_csv('import_data.csv')
df.head()
# Out:
#   mortgage_advisor_name              consumer_1_email
# 0       Vanessa Abigail  way_country_able@example.com  \
# 1                   NaN                           NaN
# 2       Vanessa Abigail  have_chap_slight@example.com
# 3                   NaN                           NaN
# 4       Vanessa Abigail    leg_some_cause@example.com
#
#               consumer_2_email consumer_1_email_validity
# 0                          NaN                     Valid  \
# 1                          NaN                       NaN
# 2   sun_play_green@example.com                     Valid
# 3                          NaN                       NaN
# 4  town_plus_bloke@example.com                     Valid
#
#   consumer_2_email_validity   consumer_1_name consumer_2_name
# 0                       NaN     Rachel Daniel             NaN  \
# 1                       NaN               NaN             NaN
# 2                     Valid     Laura Kathryn       Sam Wayne
# 3                       NaN               NaN             NaN
# 4                     Risky  Benjamin Anthony    Adrian Jenni
#
#    consumer_1_phone_number  consumer_2_phone_number
# 0             7.822269e+09                      NaN  \
# 1                      NaN                      NaN
# 2             7.848853e+09             7.576772e+09
# 3                      NaN                      NaN
# 4             7.814313e+09             7.531585e+09
#
#   consumer_1_phone_number_validity  ...   mortgage_type mortgage_payment_type
# 0                            Valid  ...  owner-occupied             repayment  \
# 1                              NaN  ...             NaN                   NaN
# 2                            Valid  ...  owner-occupied             repayment
# 3                              NaN  ...             NaN                   NaN
# 4                            Valid  ...  owner-occupied             repayment
#
#     mortgage_lender  mortgage_loan_purpose mortgage_scheme
# 0          Leeds BS               purchase           fixed  \
# 1               NaN                    NaN             NaN
# 2  Santander UK Plc        further-advance           fixed
# 3               NaN                    NaN             NaN
# 4  Santander UK Plc             remortgage           fixed
#
#      mortgage_advisor_email mortgage_account_number mortgage_description
# 0  art_miss_hit@example.com                     NaN                  NaN  \
# 1                       NaN                     NaN                  NaN
# 2  art_miss_hit@example.com                     NaN                  NaN
# 3                       NaN                     NaN                  NaN
# 4  art_miss_hit@example.com                     NaN                  NaN
#
#    mortgage_charge  mortgage_pct_owned
# 0     first-charge                 NaN
# 1              NaN                 NaN
# 2     first-charge                 NaN
# 3              NaN                 NaN
# 4     first-charge                 NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# We can see that this data looks very messy with a lot of missing values.
#
# We can look further into this by looking at a description of our data:

# %%
display(df.describe().T)
print(df.shape)
# Out:
#                                      count          mean           std
# consumer_1_phone_number             3310.0  7.780850e+09  1.506626e+08  \
# consumer_2_phone_number             2000.0  7.787510e+09  1.494500e+08
# consumer_1_correspondence_postcode     0.0           NaN           NaN
# consumer_2_correspondence_postcode     0.0           NaN           NaN
# property_value                         0.0           NaN           NaN
# mortgage_preferential_rate          3300.0  2.360197e+00  1.448875e+01
# mortgage_loan_amount                3322.0  1.591385e+05  6.196074e+04
# mortgage_property_value             2229.0  2.865802e+05  1.015140e+05
# mortgage_account_number                0.0           NaN           NaN
# mortgage_description                   0.0           NaN           NaN
# mortgage_pct_owned                   452.0  0.000000e+00  0.000000e+00
#
#                                              min           25%           50%
# consumer_1_phone_number             7.511162e+09  7.599251e+09  7.813421e+09  \
# consumer_2_phone_number             7.511132e+09  7.714090e+09  7.819519e+09
# consumer_1_correspondence_postcode           NaN           NaN           NaN
# consumer_2_correspondence_postcode           NaN           NaN           NaN
# property_value                               NaN           NaN           NaN
# mortgage_preferential_rate          8.500000e-01  1.740000e+00  1.990000e+00
# mortgage_loan_amount                2.440000e+02  1.181488e+05  1.517670e+05
# mortgage_property_value             7.500000e+04  2.150000e+05  2.700000e+05
# mortgage_account_number                      NaN           NaN           NaN
# mortgage_description                         NaN           NaN           NaN
# mortgage_pct_owned                  0.000000e+00  0.000000e+00  0.000000e+00
#
#                                              75%           max
# consumer_1_phone_number             7.898214e+09  7.999995e+09
# consumer_2_phone_number             7.917412e+09  7.999895e+09
# consumer_1_correspondence_postcode           NaN           NaN
# consumer_2_correspondence_postcode           NaN           NaN
# property_value                               NaN           NaN
# mortgage_preferential_rate          2.300000e+00  8.336700e+02
# mortgage_loan_amount                1.941412e+05  5.250000e+05
# mortgage_property_value             3.380070e+05  1.050000e+06
# mortgage_account_number                      NaN           NaN
# mortgage_description                         NaN           NaN
# mortgage_pct_owned                  0.000000e+00  0.000000e+00
# (11080, 31)

# %% [markdown]
# We can see that some our our columns are completely empty. Therefore we can create a function to remove these columns:

# %%
def drop_empty_columns(df):
    # Get the columns before dropping empty columns
    cols_before = df.columns

    # Use the dropna() function to drop columns with all NaN (empty) values
    df.dropna(axis=1, how='all', inplace=True)

    # Get the columns after dropping empty columns
    cols_after = df.columns

    # Find the removed columns
    removed_columns = set(cols_before) - set(cols_after)
    return df, removed_columns

df, removed_cols = drop_empty_columns(df)
print('Removed columns:', removed_cols)
print(df.shape)
# Out:
# Removed columns: {'mortgage_account_number', 'mortgage_description', 'consumer_2_correspondence_postcode', 'property_value', 'consumer_1_correspondence_postcode'}
# (11080, 26)

# %% [markdown]
# We can see that we have removed six columns that are useless to us since they contain no data. However, in a proper business setting we would need to evaluate the importance of these columns and investigate why we aren't collecting any information for them.
#
# We can similarly create a function to remove any completely blank rows:

# %%
def drop_empty_rows(df):
    # Get the number of rows before dropping empty rows
    rows_before = df.shape[0]

    # Use the dropna() function to drop rows with all NaN (empty) values
    df.dropna(axis=0, how='all', inplace=True)

    # Get the number of rows after dropping empty rows
    rows_after = df.shape[0]

    # Calculate the number of rows removed
    rows_removed = rows_before - rows_after
    return df, rows_removed

df, removed_rows = drop_empty_rows(df)
print('Number of removed rows:', removed_rows)
# Out:
# Number of removed rows: 7756

# %% [markdown]
# We can again look into a description of our data:

# %%
display(df.describe(include='all').T)
print(df.shape)
# Out:
#                                    count unique
# mortgage_advisor_name               3324     21  \
# consumer_1_email                    3185   2919
# consumer_2_email                    1756   1596
# consumer_1_email_validity           3185      3
# consumer_2_email_validity           1756      3
# consumer_1_name                     3324   2937
# consumer_2_name                     2423   2120
# consumer_1_phone_number           3310.0    NaN
# consumer_2_phone_number           2000.0    NaN
# consumer_1_phone_number_validity    3310      2
# consumer_1_dob                      3324   2642
# consumer_2_dob                      2139   1771
# property_address                    3301   3018
# mortgage_expiry_date                3324    714
# mortgage_start_date                 3321    286
# mortgage_preferential_rate        3300.0    NaN
# mortgage_loan_amount              3322.0    NaN
# mortgage_property_value           2229.0    NaN
# mortgage_type                       3324      2
# mortgage_payment_type               3319      2
# mortgage_lender                     3323     41
# mortgage_loan_purpose               3324      4
# mortgage_scheme                     3318      3
# mortgage_advisor_email              3324     22
# mortgage_charge                     3324      1
# mortgage_pct_owned                 452.0    NaN
#
#                                                                                 top
# mortgage_advisor_name                                                 Eleanor Sarah  \
# consumer_1_email                                 opportunity_study_find@example.com
# consumer_2_email                                   function_gas_britain@example.com
# consumer_1_email_validity                                                     Valid
# consumer_2_email_validity                                                     Valid
# consumer_1_name                                                          Amy Gurjit
# consumer_2_name                                                        Craig Elinor
# consumer_1_phone_number                                                         NaN
# consumer_2_phone_number                                                         NaN
# consumer_1_phone_number_validity                                              Valid
# consumer_1_dob                                                           1936-12-04
# consumer_2_dob                                            Tuesday, 23 February 1999
# property_address                  1 Brief This Avenue, Whetherworth, Separateshi...
# mortgage_expiry_date                                                     2021-11-01
# mortgage_start_date                                                      2023-12-31
# mortgage_preferential_rate                                                      NaN
# mortgage_loan_amount                                                            NaN
# mortgage_property_value                                                         NaN
# mortgage_type                                                        owner-occupied
# mortgage_payment_type                                                     repayment
# mortgage_lender                                                             Halifax
# mortgage_loan_purpose                                                      purchase
# mortgage_scheme                                                               fixed
# mortgage_advisor_email                          return_involve_separate@example.com
# mortgage_charge                                                        first-charge
# mortgage_pct_owned                                                              NaN
#
#                                   freq               mean               std
# mortgage_advisor_name              446                NaN               NaN  \
# consumer_1_email                    16                NaN               NaN
# consumer_2_email                    13                NaN               NaN
# consumer_1_email_validity         3059                NaN               NaN
# consumer_2_email_validity         1669                NaN               NaN
# consumer_1_name                     16                NaN               NaN
# consumer_2_name                     16                NaN               NaN
# consumer_1_phone_number            NaN  7780850386.466767  150662550.346105
# consumer_2_phone_number            NaN    7787510048.9545  149449964.979327
# consumer_1_phone_number_validity  3299                NaN               NaN
# consumer_1_dob                      17                NaN               NaN
# consumer_2_dob                      16                NaN               NaN
# property_address                    16                NaN               NaN
# mortgage_expiry_date                71                NaN               NaN
# mortgage_start_date                105                NaN               NaN
# mortgage_preferential_rate         NaN           2.360197         14.488752
# mortgage_loan_amount               NaN       159138.48826      61960.743272
# mortgage_property_value            NaN      286580.171826     101514.015535
# mortgage_type                     3224                NaN               NaN
# mortgage_payment_type             3243                NaN               NaN
# mortgage_lender                    913                NaN               NaN
# mortgage_loan_purpose             2055                NaN               NaN
# mortgage_scheme                   3236                NaN               NaN
# mortgage_advisor_email             446                NaN               NaN
# mortgage_charge                   3324                NaN               NaN
# mortgage_pct_owned                 NaN                0.0               0.0
#
#                                            min            25%           50%
# mortgage_advisor_name                      NaN            NaN           NaN  \
# consumer_1_email                           NaN            NaN           NaN
# consumer_2_email                           NaN            NaN           NaN
# consumer_1_email_validity                  NaN            NaN           NaN
# consumer_2_email_validity                  NaN            NaN           NaN
# consumer_1_name                            NaN            NaN           NaN
# consumer_2_name                            NaN            NaN           NaN
# consumer_1_phone_number           7511161541.0   7599250802.0  7813421438.0
# consumer_2_phone_number           7511132246.0  7714089587.25  7819518657.0
# consumer_1_phone_number_validity           NaN            NaN           NaN
# consumer_1_dob                             NaN            NaN           NaN
# consumer_2_dob                             NaN            NaN           NaN
# property_address                           NaN            NaN           NaN
# mortgage_expiry_date                       NaN            NaN           NaN
# mortgage_start_date                        NaN            NaN           NaN
# mortgage_preferential_rate                0.85           1.74          1.99
# mortgage_loan_amount                     244.0      118148.75      151767.0
# mortgage_property_value                75000.0       215000.0      270000.0
# mortgage_type                              NaN            NaN           NaN
# mortgage_payment_type                      NaN            NaN           NaN
# mortgage_lender                            NaN            NaN           NaN
# mortgage_loan_purpose                      NaN            NaN           NaN
# mortgage_scheme                            NaN            NaN           NaN
# mortgage_advisor_email                     NaN            NaN           NaN
# mortgage_charge                            NaN            NaN           NaN
# mortgage_pct_owned                         0.0            0.0           0.0
#
#                                            75%           max
# mortgage_advisor_name                      NaN           NaN
# consumer_1_email                           NaN           NaN
# consumer_2_email                           NaN           NaN
# consumer_1_email_validity                  NaN           NaN
# consumer_2_email_validity                  NaN           NaN
# consumer_1_name                            NaN           NaN
# consumer_2_name                            NaN           NaN
# consumer_1_phone_number           7898213662.0  7999994963.0
# consumer_2_phone_number           7917411756.0  7999895376.0
# consumer_1_phone_number_validity           NaN           NaN
# consumer_1_dob                             NaN           NaN
# consumer_2_dob                             NaN           NaN
# property_address                           NaN           NaN
# mortgage_expiry_date                       NaN           NaN
# mortgage_start_date                        NaN           NaN
# mortgage_preferential_rate                 2.3        833.67
# mortgage_loan_amount                 194141.25      525000.0
# mortgage_property_value               338007.0     1050000.0
# mortgage_type                              NaN           NaN
# mortgage_payment_type                      NaN           NaN
# mortgage_lender                            NaN           NaN
# mortgage_loan_purpose                      NaN           NaN
# mortgage_scheme                            NaN           NaN
# mortgage_advisor_email                     NaN           NaN
# mortgage_charge                            NaN           NaN
# mortgage_pct_owned                         0.0           0.0
# (3324, 26)

# %% [markdown]
# We can see that the column mortgage_charge only has one unique value which makes the row completely redundant. Therefore, we can also remove this row:

# %%
# Drop column
df = df.drop('mortgage_charge', axis=1)
print(df.shape)
# Out:
# (3324, 25)

# %% [markdown]
# We can also check to see if our dataset has any duplicated values and remove them if so:

# %%
print('Number of duplicate rows:', df.duplicated().sum())

# Drop duplicates
df = df.drop_duplicates()
print(df.shape)
# Out:
# Number of duplicate rows: 217
# (3107, 25)

# %% [markdown]
# We can look at our description of our data again to notice any other irregularities:

# %%
display(df.describe(include='all').T)
# Out:
#                                    count unique
# mortgage_advisor_name               3107     21  \
# consumer_1_email                    3007   2919
# consumer_2_email                    1643   1596
# consumer_1_email_validity           3007      3
# consumer_2_email_validity           1643      3
# consumer_1_name                     3107   2937
# consumer_2_name                     2243   2120
# consumer_1_phone_number           3094.0    NaN
# consumer_2_phone_number           1841.0    NaN
# consumer_1_phone_number_validity    3094      2
# consumer_1_dob                      3107   2642
# consumer_2_dob                      1980   1771
# property_address                    3084   3018
# mortgage_expiry_date                3107    714
# mortgage_start_date                 3105    286
# mortgage_preferential_rate        3084.0    NaN
# mortgage_loan_amount              3105.0    NaN
# mortgage_property_value           2106.0    NaN
# mortgage_type                       3107      2
# mortgage_payment_type               3102      2
# mortgage_lender                     3106     41
# mortgage_loan_purpose               3107      4
# mortgage_scheme                     3101      3
# mortgage_advisor_email              3107     22
# mortgage_pct_owned                 422.0    NaN
#
#                                                                                 top
# mortgage_advisor_name                                                 Eleanor Sarah  \
# consumer_1_email                                       reason_time_best@example.com
# consumer_2_email                                        it_summer_horse@example.com
# consumer_1_email_validity                                                     Valid
# consumer_2_email_validity                                                     Valid
# consumer_1_name                                                       Rachel Joshua
# consumer_2_name                                                       Robert Daniel
# consumer_1_phone_number                                                         NaN
# consumer_2_phone_number                                                         NaN
# consumer_1_phone_number_validity                                              Valid
# consumer_1_dob                                                           1980-12-16
# consumer_2_dob                                                  Sunday, 31 May 1970
# property_address                  243 Against Speed Close, Perworth, Groupland W...
# mortgage_expiry_date                                                     2021-11-01
# mortgage_start_date                                                      2023-12-31
# mortgage_preferential_rate                                                      NaN
# mortgage_loan_amount                                                            NaN
# mortgage_property_value                                                         NaN
# mortgage_type                                                        owner-occupied
# mortgage_payment_type                                                     repayment
# mortgage_lender                                                             Halifax
# mortgage_loan_purpose                                                      purchase
# mortgage_scheme                                                               fixed
# mortgage_advisor_email                          return_involve_separate@example.com
# mortgage_pct_owned                                                              NaN
#
#                                   freq               mean               std
# mortgage_advisor_name              446                NaN               NaN  \
# consumer_1_email                     3                NaN               NaN
# consumer_2_email                     3                NaN               NaN
# consumer_1_email_validity         2895                NaN               NaN
# consumer_2_email_validity         1560                NaN               NaN
# consumer_1_name                      3                NaN               NaN
# consumer_2_name                      4                NaN               NaN
# consumer_1_phone_number            NaN  7779464763.443439  150495601.096449
# consumer_2_phone_number            NaN   7787649939.15698  148676740.718385
# consumer_1_phone_number_validity  3084                NaN               NaN
# consumer_1_dob                       4                NaN               NaN
# consumer_2_dob                       4                NaN               NaN
# property_address                     3                NaN               NaN
# mortgage_expiry_date                65                NaN               NaN
# mortgage_start_date                 97                NaN               NaN
# mortgage_preferential_rate         NaN           2.377808         14.986647
# mortgage_loan_amount               NaN      158853.034783      62140.223059
# mortgage_property_value            NaN      286735.118234     102424.079159
# mortgage_type                     3014                NaN               NaN
# mortgage_payment_type             3031                NaN               NaN
# mortgage_lender                    868                NaN               NaN
# mortgage_loan_purpose             1924                NaN               NaN
# mortgage_scheme                   3025                NaN               NaN
# mortgage_advisor_email             446                NaN               NaN
# mortgage_pct_owned                 NaN                0.0               0.0
#
#                                            min            25%           50%
# mortgage_advisor_name                      NaN            NaN           NaN  \
# consumer_1_email                           NaN            NaN           NaN
# consumer_2_email                           NaN            NaN           NaN
# consumer_1_email_validity                  NaN            NaN           NaN
# consumer_2_email_validity                  NaN            NaN           NaN
# consumer_1_name                            NaN            NaN           NaN
# consumer_2_name                            NaN            NaN           NaN
# consumer_1_phone_number           7511161541.0  7598388748.75  7812347416.0
# consumer_2_phone_number           7511132246.0   7714789653.0  7819784286.0
# consumer_1_phone_number_validity           NaN            NaN           NaN
# consumer_1_dob                             NaN            NaN           NaN
# consumer_2_dob                             NaN            NaN           NaN
# property_address                           NaN            NaN           NaN
# mortgage_expiry_date                       NaN            NaN           NaN
# mortgage_start_date                        NaN            NaN           NaN
# mortgage_preferential_rate                0.85           1.74          1.99
# mortgage_loan_amount                     244.0       117750.0      151701.0
# mortgage_property_value                75000.0       214950.0      270000.0
# mortgage_type                              NaN            NaN           NaN
# mortgage_payment_type                      NaN            NaN           NaN
# mortgage_lender                            NaN            NaN           NaN
# mortgage_loan_purpose                      NaN            NaN           NaN
# mortgage_scheme                            NaN            NaN           NaN
# mortgage_advisor_email                     NaN            NaN           NaN
# mortgage_pct_owned                         0.0            0.0           0.0
#
#                                            75%           max
# mortgage_advisor_name                      NaN           NaN
# consumer_1_email                           NaN           NaN
# consumer_2_email                           NaN           NaN
# consumer_1_email_validity                  NaN           NaN
# consumer_2_email_validity                  NaN           NaN
# consumer_1_name                            NaN           NaN
# consumer_2_name                            NaN           NaN
# consumer_1_phone_number           7896909857.0  7999994963.0
# consumer_2_phone_number           7915588691.0  7999895376.0
# consumer_1_phone_number_validity           NaN           NaN
# consumer_1_dob                             NaN           NaN
# consumer_2_dob                             NaN           NaN
# property_address                           NaN           NaN
# mortgage_expiry_date                       NaN           NaN
# mortgage_start_date                        NaN           NaN
# mortgage_preferential_rate                 2.3        833.67
# mortgage_loan_amount                  194052.0      525000.0
# mortgage_property_value               338995.0     1050000.0
# mortgage_type                              NaN           NaN
# mortgage_payment_type                      NaN           NaN
# mortgage_lender                            NaN           NaN
# mortgage_loan_purpose                      NaN           NaN
# mortgage_scheme                            NaN           NaN
# mortgage_advisor_email                     NaN           NaN
# mortgage_pct_owned                         0.0           0.0

# %% [markdown]
# One thing of note is how there is one more mortgage_advisor_email than mortgage_advisor_name where we woud assume that these should be equal. We can look deeper into this:

# %%
def show_multiple_records_by_name(df, name_col, record_col):

    # Group by names and count the number of unique emails for each name 
    name_record_counts = df.groupby(name_col)[record_col].nunique()

    # Filter names with two or more unique emails
    names_with_multiple_records = name_record_counts[name_record_counts >= 2].index.tolist()

    return names_with_multiple_records 

print('Names with two or more emails assigned:', show_multiple_records_by_name(df, 'mortgage_advisor_name', 'mortgage_advisor_email'))
# Out:
# Names with two or more emails assigned: ['Olivia Joshua']

# %% [markdown]
# We can see that Olivia Joshua is the person with two emails associated with her name, we can look further into this:

# %%
df[df['mortgage_advisor_name']=='Olivia Joshua'][['mortgage_advisor_name', 'mortgage_advisor_email']].value_counts()
# Out:
# mortgage_advisor_name  mortgage_advisor_email
# Olivia Joshua          great_judge_relation@example.com    249
#                        air_since_particular@example.com     36
# Name: count, dtype: int64

# %% [markdown]
# We can see that one email for this mortgage advisor is a lot more prominent in the dataset. Although it is possible that she uses two emails, it is best that we update the less prominent email to her more prominent. However, first we should check that no one else uses this email and there has been a mix up on the name:

# %%
df[df['mortgage_advisor_email']=='air_since_particular@example.com']['mortgage_advisor_name'].value_counts()
# Out:
# mortgage_advisor_name
# Olivia Joshua    36
# Name: count, dtype: int64

# %% [markdown]
# Since no one else uses this email, we can confidently say that Olivia Joshua is the correct mortgage advisor here and we update her email:

# %%
def replace_with_most_popular_email(df, name, name_col, email_col):

    # Get most common email
    most_common_email = df[df[name_col]==name][[email_col]].value_counts().index[0][0]

    # We can update the email to keep it consistent
    df.loc[df[name_col]== name, email_col] = most_common_email

    return df

df = replace_with_most_popular_email(df, 'Olivia Joshua', 'mortgage_advisor_name', 'mortgage_advisor_email')

# %% [markdown]
# We can check that this has updated Olivia Josuhua's emails:

# %%
df[df['mortgage_advisor_name']=='Olivia Joshua'][['mortgage_advisor_name', 'mortgage_advisor_email']].value_counts()
# Out:
# mortgage_advisor_name  mortgage_advisor_email
# Olivia Joshua          great_judge_relation@example.com    285
# Name: count, dtype: int64

# %% [markdown]
# Now that we are happy with our mortgage advisors, we can look into other columns. First we will look into DOB as we can already see above that the date formats are not consistent:

# %%
def convert_date_format(input_date):
    if pd.isna(input_date):
        return input_date  # Return NaN as is
    else:
        # Define the input and output date formats
        input_format = "%A, %d %B %Y"
        output_format = "%d/%m/%Y"

        # Parse the input date using the input format
        date_obj = datetime.strptime(input_date, input_format)

        # Convert the date object to the desired output format
        output_date = date_obj.strftime(output_format)
        return output_date

df['consumer_2_dob'] = df['consumer_2_dob'].apply(convert_date_format)

# %% [markdown]
# We can sense check these date of births:

# %%
print('Min. consumer 1 DOB:', pd.to_datetime(df['consumer_1_dob']).min())
print('Min. consumer 2 DOB:', pd.to_datetime(df['consumer_2_dob']).min())
# Out:
# Min. consumer 1 DOB: 1920-01-07 00:00:00
# C:\Users\samke\AppData\Local\Temp\ipykernel_21084\3153728012.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   print('Min. consumer 2 DOB:', pd.to_datetime(df['consumer_2_dob']).min())
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[687], line 2
#       1 print('Min. consumer 1 DOB:', pd.to_datetime(df['consumer_1_dob']).min())
# ----> 2 print('Min. consumer 2 DOB:', pd.to_datetime(df['consumer_2_dob']).min())
#
# File c:\Users\samke\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File c:\Users\samke\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
#     251     # GH#45319
#     252     try:
#
# File c:\Users\samke\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:455, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     452 if format is not None and format != "mixed":
#     453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#     458     yearfirst=yearfirst,
#     459     utc=utc,
#     460     errors=errors,
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#     467     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File c:\Users\samke\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, allow_object)
#    2174 # if str-dtype, convert
#    2175 data = np.array(data, copy=False, dtype=np.object_)
# -> 2177 result, tz_parsed = tslib.array_to_datetime(
#    2178     data,
#    2179     errors=errors,
#    2180     utc=utc,
#    2181     dayfirst=dayfirst,
#    2182     yearfirst=yearfirst,
#    2183 )
#    2185 if tz_parsed is not None:
#    2186     # We can take a shortcut since the datetime64 numpy array
#    2187     #  is in UTC
#    2188     # Return i8 values to denote unix timestamps
#    2189     return result.view("i8"), tz_parsed
#
# File c:\Users\samke\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:402, in pandas._libs.tslib.array_to_datetime()
#
# File c:\Users\samke\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:551, in pandas._libs.tslib.array_to_datetime()
#
# File c:\Users\samke\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:516, in pandas._libs.tslib.array_to_datetime()
#
# File c:\Users\samke\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslibs\conversion.pyx:557, in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
#
# File c:\Users\samke\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslibs\parsing.pyx:329, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File c:\Users\samke\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslibs\parsing.pyx:658, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# DateParseError: Unknown datetime string format, unable to parse: No second consumer, at position 0

# %% [markdown]
# We can see that our oldest consumers are both over 100 years old. Since this is possible we will keep the values but with more time we may want to look deeper into these records to ensure they are still relevant.

# %% [markdown]
# We can now look into how many consumers have multiple date of births to their name:

# %%
print('Number of consumers that have multiple date of births to their name (consumer 1):', len(show_multiple_records_by_name(df, 'consumer_1_name', 'consumer_1_dob')))
print('Number of consumers that have multiple date of births to their name (consumer 2):', len(show_multiple_records_by_name(df, 'consumer_2_name', 'consumer_2_dob')))
# Out:
# Number of consumers that have multiple date of births to their name (consumer 1): 82
# Number of consumers that have multiple date of births to their name (consumer 2): 44

# %% [markdown]
# We can see that some consumers have multiple DOBs which is illogical. This is likely due to consumers sharing names so we need to create a consumer ID for each consumer so that we can distinguish between these consumers:

# %%
df['consumer_1_ID'] = df['consumer_1_name'] + '_' + df['consumer_1_dob'].astype(str) 
df['consumer_2_ID'] = df['consumer_2_name'] + '_' + df['consumer_2_dob'].astype(str)

# %%
print('Number of consumer IDs that have multiple date of births to their ID:', len(show_multiple_records_by_name(df, 'consumer_1_ID', 'consumer_1_dob')))
print('Number of consumer IDs that have multiple date of births to their ID:', len(show_multiple_records_by_name(df, 'consumer_2_ID', 'consumer_2_dob')))
# Out:
# Number of consumer IDs that have multiple date of births to their ID: 0
# Number of consumer IDs that have multiple date of births to their ID: 0

# %% [markdown]
# Now after re-running the code with ID instead of name, we can see above that there are no customers with multiple DOBs. We can also check that no customer have multiple emails or phone numbers for each ID:

# %%
print('Consumers with multiple emails (consumer 1): ', show_multiple_records_by_name(df, 'consumer_1_ID', 'consumer_1_email'))
print('Consumers with multiple emails (consumer 2): ', show_multiple_records_by_name(df, 'consumer_2_ID', 'consumer_2_email'))
print('Consumers with multiple phone numbers (consumer 1): ', show_multiple_records_by_name(df, 'consumer_1_ID', 'consumer_1_phone_number'))
print('Consumers with multiple phone numbers (consumer 2): ', show_multiple_records_by_name(df, 'consumer_2_ID', 'consumer_2_phone_number'))
# Out:
# Consumers with multiple emails (consumer 1):  []
# Consumers with multiple emails (consumer 2):  ['Rochelle Imran_28/01/1968']
# Consumers with multiple phone numbers (consumer 1):  []
# Consumers with multiple phone numbers (consumer 2):  ['Rochelle Imran_28/01/1968']

# %% [markdown]
# We can see there is only one consumer where this is the case so we can look into this consumer:

# %%
df[df['consumer_2_ID'] == 'Rochelle Imran_28/01/1968'][['consumer_1_name', 'consumer_2_name', 'consumer_1_email', 'consumer_2_email', 'consumer_1_phone_number', 'consumer_2_phone_number']]
# Out:
#      consumer_1_name consumer_2_name             consumer_1_email
# 551    Samantha Jack  Rochelle Imran  small_miss_past@example.com  \
# 3228   Samantha Jack  Rochelle Imran  small_miss_past@example.com
#
#                  consumer_2_email  consumer_1_phone_number
# 551   clear_back_best@example.com             7.859950e+09  \
# 3228  small_miss_past@example.com             7.859950e+09
#
#       consumer_2_phone_number
# 551              7.582672e+09
# 3228             7.859950e+09

# %% [markdown]
# We can see that this is simply an error where the consumer 1's email and phone has been inputted into the consumer 2 field. Therefore, we can ammend this:

# %%
df.loc[df['consumer_2_ID'] == 'Rochelle Imran_28/01/1968', 'consumer_2_email'] = 'clear_back_best@example.com'
df.loc[df['consumer_2_ID'] == 'Rochelle Imran_28/01/1968', 'consumer_2_phone_number'] = '7582672214'

# %%
print('Consumers with multiple emails (consumer 1): ', show_multiple_records_by_name(df, 'consumer_1_ID', 'consumer_1_email'))
print('Consumers with multiple emails (consumer 2): ', show_multiple_records_by_name(df, 'consumer_2_ID', 'consumer_2_email'))
print('Consumers with multiple phone numbers (consumer 1): ', show_multiple_records_by_name(df, 'consumer_1_ID', 'consumer_1_phone_number'))
print('Consumers with multiple phone numbers (consumer 2): ', show_multiple_records_by_name(df, 'consumer_2_ID', 'consumer_2_phone_number'))
# Out:
# Consumers with multiple emails (consumer 1):  []
# Consumers with multiple emails (consumer 2):  []
# Consumers with multiple phone numbers (consumer 1):  []
# Consumers with multiple phone numbers (consumer 2):  []

# %% [markdown]
# Re-running the above code we can see that there are no longer any consumers with multiple emails or phone numbers to their name.
#
# Since we have missing values for consumer emails and consumer phone numbers, we can see if we can impute these from the consumer ID:

# %%
def replace_missing_email_phone(df):
    # Get null counts before replacing missing values
    email_null_count_1 = df["consumer_1_email"].isnull().sum()
    email_null_count_2 = df["consumer_2_email"].isnull().sum()
    phone_null_count_1 = df["consumer_1_phone_number"].isnull().sum()
    phone_null_count_2 = df["consumer_2_phone_number"].isnull().sum()

    # Forward-fill missing values for email and phone number columns within each group
    df["consumer_1_email"] = df.groupby("consumer_1_ID")["consumer_1_email"].transform(lambda x: x.fillna(method="ffill"))
    df["consumer_2_email"] = df.groupby("consumer_2_ID")["consumer_2_email"].transform(lambda x: x.fillna(method="ffill"))
    df["consumer_1_phone_number"] = df.groupby("consumer_1_ID")["consumer_1_phone_number"].transform(lambda x: x.fillna(method="ffill"))
    df["consumer_2_phone_number"] = df.groupby("consumer_2_ID")["consumer_2_phone_number"].transform(lambda x: x.fillna(method="ffill"))

    # Get null counts after replacing missing values
    print(email_null_count_1 - df["consumer_1_email"].isnull().sum(), 'missing emails replaced (consumer 1)')
    print(email_null_count_2 - df["consumer_2_email"].isnull().sum(), 'missing emails replaced (consumer 2)')
    print(phone_null_count_1 - df["consumer_1_phone_number"].isnull().sum(), 'missing phone numbers replaced (consumer 1)')
    print(phone_null_count_2 - df["consumer_2_phone_number"].isnull().sum(), 'missing phone numbers replaced (consumer 2)')

    return df

df = replace_missing_email_phone(df)
# Out:
# 0 missing emails replaced (consumer 1)
# 0 missing emails replaced (consumer 2)
# 0 missing phone numbers replaced (consumer 1)
# 0 missing phone numbers replaced (consumer 2)

# %% [markdown]
# We can see that we were unfortunately unable to impute any missing emails and phone_numbers from their associated pairs. We could spemd longer looking into this data to try and and impute a consumer's name or email from other data, however due to time constraints we will simply replace any missing value with 'Unknown'. We can also update the email_validity and phone_validity columns to add a third value 'No email' or 'No phone number' respectively:

# %%
# Fill nan emails and phone numbers with Unknown
df['consumer_1_email'].fillna('Unknown', inplace=True)
df['consumer_2_email'].fillna('Unknown', inplace=True)
df['consumer_1_phone_number'].fillna('Unknown', inplace=True)
df['consumer_2_phone_number'].fillna('Unknown', inplace=True)

# Update validity columns
df.loc[df['consumer_1_email']=='Unknown', 'consumer_1_email_validity'] = 'No email'
df.loc[df['consumer_2_email']=='Unknown', 'consumer_2_email_validity'] = 'No email'
df.loc[df['consumer_1_phone_number']=='Unknown', 'consumer_1_phone_number_validity'] = 'No phone number'

# %% [markdown]
# We can also assume that any missing values for consumer_2_name are due to there being no second consumer. Therefore, we can replace all NaN values with 'No second consumer' and update the ID, DOB, email and phone number to say the same:

# %%
# Fill NaN columns
df['consumer_2_name'].fillna('No second consumer', inplace=True)

# Update other columns
df.loc[df['consumer_2_name']=='No second consumer', 'consumer_2_dob'] = 'No second consumer'
df.loc[df['consumer_2_name']=='No second consumer', 'consumer_2_email'] = 'No second consumer'
df.loc[df['consumer_2_name']=='No second consumer', 'consumer_2_phone_number'] = 'No second consumer'
df.loc[df['consumer_2_name']=='No second consumer', 'consumer_2_ID'] = 'No second consumer'

# %% [markdown]
# We can look at a description of our data again:

# %%
df.describe(include='all').T
# Out:
#                                    count unique
# mortgage_advisor_name               3107     21  \
# consumer_1_email                    3107   2920
# consumer_2_email                    3107   1597
# consumer_1_email_validity           3107      4
# consumer_2_email_validity           3107      4
# consumer_1_name                     3107   2937
# consumer_2_name                     3107   2121
# consumer_1_phone_number             3107   3009
# consumer_2_phone_number             3107   1788
# consumer_1_phone_number_validity    3107      3
# consumer_1_dob                      3107   2642
# consumer_2_dob                      2844   1772
# property_address                    3084   3018
# mortgage_expiry_date                3107    714
# mortgage_start_date                 3105    286
# mortgage_preferential_rate        3084.0    NaN
# mortgage_loan_amount              3105.0    NaN
# mortgage_property_value           2106.0    NaN
# mortgage_type                       3107      2
# mortgage_payment_type               3102      2
# mortgage_lender                     3106     41
# mortgage_loan_purpose               3107      4
# mortgage_scheme                     3101      3
# mortgage_advisor_email              3107     21
# mortgage_pct_owned                 422.0    NaN
# consumer_1_ID                       3107   3022
# consumer_2_ID                       3107   2188
#
#                                                                                 top
# mortgage_advisor_name                                                 Eleanor Sarah  \
# consumer_1_email                                                            Unknown
# consumer_2_email                                                 No second consumer
# consumer_1_email_validity                                                     Valid
# consumer_2_email_validity                                                     Valid
# consumer_1_name                                                       Rachel Joshua
# consumer_2_name                                                  No second consumer
# consumer_1_phone_number                                                     Unknown
# consumer_2_phone_number                                          No second consumer
# consumer_1_phone_number_validity                                              Valid
# consumer_1_dob                                                           1980-12-16
# consumer_2_dob                                                   No second consumer
# property_address                  243 Against Speed Close, Perworth, Groupland W...
# mortgage_expiry_date                                                     2021-11-01
# mortgage_start_date                                                      2023-12-31
# mortgage_preferential_rate                                                      NaN
# mortgage_loan_amount                                                            NaN
# mortgage_property_value                                                         NaN
# mortgage_type                                                        owner-occupied
# mortgage_payment_type                                                     repayment
# mortgage_lender                                                             Halifax
# mortgage_loan_purpose                                                      purchase
# mortgage_scheme                                                               fixed
# mortgage_advisor_email                          return_involve_separate@example.com
# mortgage_pct_owned                                                              NaN
# consumer_1_ID                                              Sandra Liston_1944-01-22
# consumer_2_ID                                                    No second consumer
#
#                                   freq           mean            std      min
# mortgage_advisor_name              446            NaN            NaN      NaN  \
# consumer_1_email                   100            NaN            NaN      NaN
# consumer_2_email                   864            NaN            NaN      NaN
# consumer_1_email_validity         2895            NaN            NaN      NaN
# consumer_2_email_validity         1560            NaN            NaN      NaN
# consumer_1_name                      3            NaN            NaN      NaN
# consumer_2_name                    864            NaN            NaN      NaN
# consumer_1_phone_number             13            NaN            NaN      NaN
# consumer_2_phone_number            864            NaN            NaN      NaN
# consumer_1_phone_number_validity  3084            NaN            NaN      NaN
# consumer_1_dob                       4            NaN            NaN      NaN
# consumer_2_dob                     864            NaN            NaN      NaN
# property_address                     3            NaN            NaN      NaN
# mortgage_expiry_date                65            NaN            NaN      NaN
# mortgage_start_date                 97            NaN            NaN      NaN
# mortgage_preferential_rate         NaN       2.377808      14.986647     0.85
# mortgage_loan_amount               NaN  158853.034783   62140.223059    244.0
# mortgage_property_value            NaN  286735.118234  102424.079159  75000.0
# mortgage_type                     3014            NaN            NaN      NaN
# mortgage_payment_type             3031            NaN            NaN      NaN
# mortgage_lender                    868            NaN            NaN      NaN
# mortgage_loan_purpose             1924            NaN            NaN      NaN
# mortgage_scheme                   3025            NaN            NaN      NaN
# mortgage_advisor_email             446            NaN            NaN      NaN
# mortgage_pct_owned                 NaN            0.0            0.0      0.0
# consumer_1_ID                        3            NaN            NaN      NaN
# consumer_2_ID                      864            NaN            NaN      NaN
#
#                                        25%       50%       75%        max
# mortgage_advisor_name                  NaN       NaN       NaN        NaN
# consumer_1_email                       NaN       NaN       NaN        NaN
# consumer_2_email                       NaN       NaN       NaN        NaN
# consumer_1_email_validity              NaN       NaN       NaN        NaN
# consumer_2_email_validity              NaN       NaN       NaN        NaN
# consumer_1_name                        NaN       NaN       NaN        NaN
# consumer_2_name                        NaN       NaN       NaN        NaN
# consumer_1_phone_number                NaN       NaN       NaN        NaN
# consumer_2_phone_number                NaN       NaN       NaN        NaN
# consumer_1_phone_number_validity       NaN       NaN       NaN        NaN
# consumer_1_dob                         NaN       NaN       NaN        NaN
# consumer_2_dob                         NaN       NaN       NaN        NaN
# property_address                       NaN       NaN       NaN        NaN
# mortgage_expiry_date                   NaN       NaN       NaN        NaN
# mortgage_start_date                    NaN       NaN       NaN        NaN
# mortgage_preferential_rate            1.74      1.99       2.3     833.67
# mortgage_loan_amount              117750.0  151701.0  194052.0   525000.0
# mortgage_property_value           214950.0  270000.0  338995.0  1050000.0
# mortgage_type                          NaN       NaN       NaN        NaN
# mortgage_payment_type                  NaN       NaN       NaN        NaN
# mortgage_lender                        NaN       NaN       NaN        NaN
# mortgage_loan_purpose                  NaN       NaN       NaN        NaN
# mortgage_scheme                        NaN       NaN       NaN        NaN
# mortgage_advisor_email                 NaN       NaN       NaN        NaN
# mortgage_pct_owned                     0.0       0.0       0.0        0.0
# consumer_1_ID                          NaN       NaN       NaN        NaN
# consumer_2_ID                          NaN       NaN       NaN        NaN

# %% [markdown]
# We are still missing values for several columns. Some of these could be of importance and should be filled with further research, however due to time constraints we will fill with 'Unknown' for several of these columns:

# %%
# Fill NaN columns
df[['consumer_2_dob', 'property_address', 'mortgage_start_date']] = df[['consumer_2_dob', 'property_address', 'mortgage_start_date']].fillna('Unknown')

# %% [markdown]
# We can look into the value counts of mortgage_pct_owned:

# %%
df['mortgage_pct_owned'].value_counts()
# Out:
# mortgage_pct_owned
# 0.0    422
# Name: count, dtype: int64

# %% [markdown]
# Since this column only contains one value we can consider it redundant and drop it:

# %%
df.drop('mortgage_pct_owned', axis=1, inplace=True)

# %% [markdown]
# For our remaining columns with missing values, these are all fairly important features such as the mortgage property value and the mortgage preferential rate. If we wanted our dataset to be as accurate as possible we should do some further research into these features to find the missing values or mark them as Unknown so that we know that this data was missing if we were to look into particular cases at a later date.
#
# However, if we wanted to perform some general analysis on our dataset as a whole and the complete accuracy of our data on a case by case basis was of less importance, we could impute these missing values based on the rest of the data in our dataset.
#
# We will assume the latter and impute the missing values. To do this we will use replace the categorical features with the most common value and use a KNN imputer to fill the missing numerical values:

# %%
# Get a list of categorical features
categorical_features = df.select_dtypes(include=['object']).columns.tolist()

# Fill missing values in categorical columns with the mode of each column
for feature in categorical_features:
    df[feature] = df[feature].fillna(df[feature].mode().iloc[0])

# %%
# Get a list of numerical features
numerical_features = df.select_dtypes(include=['number']).columns.tolist()

# Impute missing values
imputer = KNNImputer(n_neighbors=5)
df[numerical_features] = imputer.fit_transform(df[numerical_features])

# %% [markdown]
# We can check that our dataset contains no more missing values:

# %%
print('Total missing values:', df.isna().sum().sum())
# Out:
# Total missing values: 0

# %% [markdown]
# Finally we can save to a csv file:

# %%
df.to_csv('import_data_clean.csv', index=False)

# %% [markdown]
# We can also run the whole cleaning process through a Python module:

# %%
from task1_pipeline import clean_data

clean_data('import_data.csv', 'import_data_clean.csv')
# Out:
# 0 missing emails replaced (consumer 1)
# 0 missing emails replaced (consumer 2)
# 0 missing phone numbers replaced (consumer 1)
# 0 missing phone numbers replaced (consumer 2)
# Total missing values: 0
